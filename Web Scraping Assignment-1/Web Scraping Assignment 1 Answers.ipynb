# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
title = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('All header tags :', *title, sep='\n\n')
# Out:
# All header tags :
#
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none"><span class="mw-page-title-main">Main Page</span></h1>
#
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# ...

# %%
# Part a) Top 10 ODI teams

# Find the table containing the top 10 ODI teams
teams_table = soup.find("table", class_="table")

teams_data = []
for row in teams_table.find_all("tr")[1:]:
    columns = row.find_all("td")
    team = columns[1].get_text(strip=True)
    matches = columns[2].get_text(strip=True)
    points = columns[3].get_text(strip=True)
    rating = columns[4].get_text(strip=True)
    teams_data.append((team, matches, points, rating))

# Create DataFrame for top 10 ODI teams
teams_df = pd.DataFrame(teams_data, columns=["Team", "Matches", "Points", "Rating"])

print("Top 10 ODI Teams:")
print(teams_df)
print("\n")

# Part b) Top 10 ODI Batsmen

# URL for top 10 ODI batsmen
batsmen_url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi"

batsmen_response = requests.get(batsmen_url)
batsmen_soup = BeautifulSoup(batsmen_response.content, "html.parser")

batsmen_table = batsmen_soup.find("table", class_="table")

batsmen_data = []
for row in batsmen_table.find_all("tr")[1:11]:
    columns = row.find_all("td")
    batsman = columns[1].get_text(strip=True)
    team = columns[2].get_text(strip=True)
    rating = columns[3].get_text(strip=True)
    batsmen_data.append((batsman, team, rating))

# Create DataFrame for top 10 ODI batsmen
batsmen_df = pd.DataFrame(batsmen_data, columns=["Batsman", "Team", "Rating"])

print("Top 10 ODI Batsmen:")
print(batsmen_df)
print("\n")

# Part c) Top 10 ODI Bowlers

# URL for top 10 ODI bowlers
bowlers_url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi"

bowlers_response = requests.get(bowlers_url)
bowlers_soup = BeautifulSoup(bowlers_response.content, "html.parser")

bowlers_table = bowlers_soup.find_all("table", class_="table")[1]

bowlers_data = []
for row in bowlers_table.find_all("tr")[1:11]:
    columns = row.find_all("td")
    bowler = columns[1].get_text(strip=True)
    team = columns[2].get_text(strip=True)
    rating = columns[3].get_text(strip=True)
    bowlers_data.append((bowler, team, rating))

# Create DataFrame for top 10 ODI bowlers
bowlers_df = pd.DataFrame(bowlers_data, columns=["Bowler", "Team", "Rating"])

print("Top 10 ODI Bowlers:")
print(bowlers_df)
# Out:
# Top 10 ODI Teams:
#                 Team Matches Points Rating
# 0       AustraliaAUS      23  2,714    118
# 1        PakistanPAK      20  2,316    116
# 2           IndiaIND      36  4,081    113
# 3      New ZealandNZ      27  2,806    104
# 4         EnglandENG      24  2,426    101
# 5     South AfricaSA      19  1,910    101
# 6      BangladeshBAN      28  2,661     95
# 7     AfghanistanAFG      16  1,404     88
# 8        Sri LankaSL      32  2,794     87
# 9      West IndiesWI      38  2,582     68
# 10       ZimbabweZIM      30  1,641     55
# 11       ScotlandSCO      33  1,662     50
# 12        IrelandIRE      24  1,052     44
# 13    NetherlandsNED      28  1,044     37
# 14          NepalNEP      40  1,396     35
# 15        NamibiaNAM      28    813     29
# 16  United StatesUSA      31    808     26
# 17           OmanOMA      24    525     22
# 18            UAEUAE      41    617     15
#
#
# Top 10 ODI Batsmen:
#                  Batsman Team Rating
# ...

# %%
# Part a) Top 10 ODI teams

# Find the table containing the top 10 ODI teams
teams_table = soup.find("table", class_="table")

teams_data = []
for row in teams_table.find_all("tr")[1:]:
    columns = row.find_all("td")
    team = columns[1].get_text(strip=True)
    matches = columns[2].get_text(strip=True)
    points = columns[3].get_text(strip=True)
    rating = columns[4].get_text(strip=True)
    teams_data.append((team, matches, points, rating))

# Create DataFrame for top 10 ODI teams
teams_df = pd.DataFrame(teams_data, columns=["Team", "Matches", "Points", "Rating"])

print("Top 10 ODI Teams:")
print(teams_df)
print("\n")

# Part b) Top 10 ODI Batsmen

# URL for top 10 ODI batsmen
batsmen_url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi"

batsmen_response = requests.get(batsmen_url)
batsmen_soup = BeautifulSoup(batsmen_response.content, "html.parser")

batsmen_table = batsmen_soup.find("table", class_="table")

batsmen_data = []
for row in batsmen_table.find_all("tr")[1:11]:
    columns = row.find_all("td")
    batsman = columns[1].get_text(strip=True)
    team = columns[2].get_text(strip=True)
    rating = columns[3].get_text(strip=True)
    batsmen_data.append((batsman, team, rating))

# Create DataFrame for top 10 ODI batsmen
batsmen_df = pd.DataFrame(batsmen_data, columns=["Batsman", "Team", "Rating"])

print("Top 10 ODI Batsmen:")
print(batsmen_df)
print("\n")

# Part c) Top 10 ODI Bowlers

# URL for top 10 ODI bowlers
bowlers_url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi"

bowlers_response = requests.get(bowlers_url)
bowlers_soup = BeautifulSoup(bowlers_response.content, "html.parser")

bowlers_table = bowlers_soup.find_all("table", class_="table")[1]

bowlers_data = []
for row in bowlers_table.find_all("tr")[1:11]:
    columns = row.find_all("td")
    bowler = columns[1].get_text(strip=True)
    team = columns[2].get_text(strip=True)
    rating = columns[3].get_text(strip=True)
    bowlers_data.append((bowler, team, rating))

# Create DataFrame for top 10 ODI bowlers
bowlers_df = pd.DataFrame(bowlers_data, columns=["Bowler", "Team", "Rating"])

print("Top 10 ODI Bowlers:")
print(bowlers_df)
# Out:
# Top 10 ODI Teams:
#                 Team Matches Points Rating
# 0       AustraliaAUS      23  2,714    118
# 1        PakistanPAK      20  2,316    116
# 2           IndiaIND      36  4,081    113
# 3      New ZealandNZ      27  2,806    104
# 4         EnglandENG      24  2,426    101
# 5     South AfricaSA      19  1,910    101
# 6      BangladeshBAN      28  2,661     95
# 7     AfghanistanAFG      16  1,404     88
# 8        Sri LankaSL      32  2,794     87
# 9      West IndiesWI      38  2,582     68
# 10       ZimbabweZIM      30  1,641     55
# 11       ScotlandSCO      33  1,662     50
# 12        IrelandIRE      24  1,052     44
# 13    NetherlandsNED      28  1,044     37
# 14          NepalNEP      40  1,396     35
# 15        NamibiaNAM      28    813     29
# 16  United StatesUSA      31    808     26
# 17           OmanOMA      24    525     22
# 18            UAEUAE      41    617     15
#
#
# Top 10 ODI Batsmen:
#                Batsman Team Rating
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the CNBC news page
url = "https://www.cnbc.com/world/?region=world"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Find the div containing the news articles
news_div = soup.find("div", class_="Card-titleContainer")

# Create empty lists to store data
headlines = []
times = []
news_links = []

# Extract data from the news div
for article in news_div.find_all("a", class_="Card-titleLink"):
    headline = article.get_text(strip=True)
    headlines.append(headline)
    
    news_link = article.get("href")
    news_links.append(news_link)

for time in news_div.find_all("div", class_="Card-time"):
    times.append(time.get_text(strip=True))

# Create a DataFrame
data = {
    "Headline": headlines,
    "Time": times,
    "NewsLink": news_links
}

df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: [Headline, Time, NewsLink]
# Index: []

# %%
url=' https://www.cnbc.com/world/?region=world'
response = requests.get(url)

import requests
from bs4 import BeautifulSoup

url='https://www.bbc.com/news'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')
headlines = soup.find('body').find_all('h3')
for x in headlines:
    print(x.text.strip())
# Out:
# Strike on Ukrainian city kills seven, including a child, and injures 117
# Strike on Ukrainian city kills seven, including a child, and injures 117
# Concerns at power of inquiry into UK nurse who killed babies
# Fifa Women's World Cup: Sweden beat co-hosts Australia to claim third
# What I learned about Lucy Letby after 10 months in court
# A show taking on all that's wrong with Indian weddings
# Michael Jackson sex abuse lawsuits can be revived
# Japan-S Korea summit is coup for Biden, but will relations hold?
# India's lunar lander sends close-up photos of Moon
# Sweden beat Australia to end third at World Cup
# Wildfires engulf Canada homes as evacuation quickens
# Canada wildfires: The past 48 hours in 75 seconds
# Wildfires engulf Canada homes as evacuation quickens
# Canada wildfires: The past 48 hours in 75 seconds
# Quake hits Colombian live TV show
# Hurricane Hilary churns towards California
# US allows allies to give Ukraine F-16 war planes
# ...
